# %%
import numpy as np
import pandas as pd
import dicom as dicom
import os
import scipy.ndimage
import pickle
import matplotlib.pyplot as plt
from skimage import measure
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
def load_dicom(path):
    slices = [dicom.read_file(path + '/' + s) for s in os.listdir(path)]
    slices.sort(key = lambda x: float(x.ImagePositionPatient[2]))
    
    # The Image Position specifies the x, y, and z coords of the upper left hand corner of the image
    z_depths = [s.ImagePositionPatient[2] for s in slices]
    if len(set(z_depths))<len(z_depths):
        print ('Duplicate slices for same z-depth - ID:',path[-32:])
        slices.sort(key = lambda x: x.InstanceNumber)
        acq_num = int(np.mean([s.AcquisitionNumber for s in slices]))
        slices = [s for s in slices if s.AcquisitionNumber==acq_num]

    slice_thickness = np.abs(slices[0].ImagePositionPatient[2] - slices[1].ImagePositionPatient[2])
    if slice_thickness == 0:
        print ('Patient with slice thickness of 0 - ID:',path[-32:])
        assert False     
    x,y = slices[0].ImagePositionPatient[:2]
    
    for s in slices:
        s.SliceThickness = slice_thickness
        if s.ImagePositionPatient[0] != x or s.ImagePositionPatient[1] != y:
            print ('Patient x and y not aligned - ID:',path[-32:])
            assert False
        if 'SliceLocation' not in s:
            print ('Patient slice has no SliceLocation - ID:', path[-32:])
            assert False
        if np.abs(s.SliceLocation) != np.abs(s.ImagePositionPatient[2]):
            print ('Patient SliceLocation does not equal Imageposition - ID:', path[-32:])
            print ('SliceLocation',s.SliceLocation,'ImagePositionPatient[2]',s.ImagePositionPatient[2])
            assert False
        
        orient = list(map(float, s.ImageOrientationPatient))
        if orient != [1, 0, 0, 0, 1, 0]:
            print ('Patient has bad orientation - ID:', path[-32:])
            assert False
            
    return slices

# %%
def dicom_HU(scan):
    image = np.stack([s.pixel_array*s.RescaleSlope+s.RescaleIntercept for s in scan],axis=2).astype(np.int16)
    image[image < -1990] = -1000

    return np.array(image)

# %%
def dicom_resample(image, scan, new_spacing=[1,1,1]):
    # Determine current pixel spacing
    spacing = np.array(scan[0].PixelSpacing + [scan[0].SliceThickness], dtype=np.float32)
    #print spacing
    resize_factor = spacing / new_spacing
    new_real_shape = image.shape * resize_factor
    new_shape = np.round(new_real_shape)
    real_resize_factor = new_shape / image.shape
    new_spacing = spacing / real_resize_factor
    #print new_spacing, real_resize_factor
    image = scipy.ndimage.interpolation.zoom(image, real_resize_factor)
    
    image = np.clip(image,-1000,400)
    image = np.transpose(image, (1,0,2))
    return image

# %%
def main():
    path_raw = '/home/gantos/data/stage1/'
    path_save = '/home/gantos/stage1_arrays/'

    patients = os.listdir(path_raw)

    errors = []
    mins = []

    for patient in patients:
        try:
            scan = load_dicom(path_raw+patient)
        except:
            errors.append(patient)
            continue
        hu = dicom_HU(scan)
        mins.append(np.min(hu))
        px_rescaled = dicom_resample(hu, scan, new_spacing=[1,1,1])

        np.save(path_save+patient+'.npy',px_rescaled)
        
        if patients.index(patient)%20==0:
            print (patients.index(patient),'of',len(patients))
    
    with open(path_save+'errors_preprocessing.txt','wb') as fp:
        pickle.dump(errors, fp)
    with open(path_save+'mins_preprocessing.txt','wb') as fp:
        pickle.dump(errors, fp)

# %%
main()
# Out:
# 0 of 1595
# 20 of 1595
# 40 of 1595
# Patient SliceLocation does not equal Imageposition - ID: ba71b330a16e8b4c852f9a8730ee33b9
# SliceLocation +366.70 ImagePositionPatient[2] 1516.800000
# Patient SliceLocation does not equal Imageposition - ID: 4b28f147cb82baba3edcdbd34ca19085
# SliceLocation +321.00 ImagePositionPatient[2] 1383.500000
# 60 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 31136e50b7205e9184227f94cdea0090
# SliceLocation +310.50 ImagePositionPatient[2] 1533.000000
# Patient SliceLocation does not equal Imageposition - ID: 990fbe3f0a1b53878669967b9afd1441
# SliceLocation 370.70 ImagePositionPatient[2] 1573.80005
# 80 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 5518b27f000e34cf2db5a362f4fac613
# SliceLocation +351.00 ImagePositionPatient[2] 1470.500000
# Patient SliceLocation does not equal Imageposition - ID: 7eb217c0444e5d866bd462ade5266a06
# SliceLocation +357.00 ImagePositionPatient[2] 1249.000000
# Patient SliceLocation does not equal Imageposition - ID: 3d5351d09a432a8de88e5b270d419ebf
# SliceLocation +332.70 ImagePositionPatient[2] 1492.800000
# Patient slice has no SliceLocation - ID: efd5b9e8cb651e18eba6a9623e36e7be
# Patient SliceLocation does not equal Imageposition - ID: baf842dd446ce9d7082efe16d22fb971
# SliceLocation +318.00 ImagePositionPatient[2] 1317.500000
# Patient SliceLocation does not equal Imageposition - ID: 3f37745d6516c29c597b797c50fe7839
# SliceLocation +365.00 ImagePositionPatient[2] 1328.500000
# Patient SliceLocation does not equal Imageposition - ID: e6160ed0ff2eb214abd4df9a3c336c1d
# SliceLocation 245.95 ImagePositionPatient[2] -245.949982
# 100 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 8e7638040431e1d91dffa4497f7078d9
# SliceLocation +339.50 ImagePositionPatient[2] 1388.500000
# Patient SliceLocation does not equal Imageposition - ID: 1a41350d4bbd74b7e0e28239cefa84c2
# SliceLocation +301.00 ImagePositionPatient[2] 1570.500000
# 120 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 84402e42c992259ac8cdd98b51d4fba3
# SliceLocation +396.00 ImagePositionPatient[2] 1342.500000
# 140 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 9b871732b3935661e7639e84a6ab9747
# SliceLocation +307.00 ImagePositionPatient[2] 1411.000000
# Patient SliceLocation does not equal Imageposition - ID: 5765dc0dbc8c02a4c862563eac4950ef
# SliceLocation 354.70 ImagePositionPatient[2] 1495.80005
# 160 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 1a91ca95390756518700877893ac195b
# SliceLocation +312.00 ImagePositionPatient[2] 1416.000000
# 180 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 8d5c4cc78e964463699c19003be70851
# SliceLocation +307.00 ImagePositionPatient[2] 945.500000
# 200 of 1595
# Patient SliceLocation does not equal Imageposition - ID: d7713d80767cfdaad5e3db537849d8d0
# SliceLocation +345.40 ImagePositionPatient[2] 1358.599000
# Patient SliceLocation does not equal Imageposition - ID: 85d59b470b927e825937ea3483571c6d
# SliceLocation 273.70 ImagePositionPatient[2] 1385.80005
# 220 of 1595
# Patient SliceLocation does not equal Imageposition - ID: bedec8e1ad130a08faeec8ed81780d56
# SliceLocation +345.30 ImagePositionPatient[2] 1494.699000
# Patient SliceLocation does not equal Imageposition - ID: 2f4e4a808cfb348d6ddc81de96f72077
# SliceLocation +322.00 ImagePositionPatient[2] 1323.000000
# 240 of 1595
# Patient SliceLocation does not equal Imageposition - ID: d73fda3be1180e4465df6fbef8a0648d
# SliceLocation +322.00 ImagePositionPatient[2] 1353.500000
# Patient SliceLocation does not equal Imageposition - ID: 85d6fb4a08853d370935a75de7495a27
# SliceLocation +387.60 ImagePositionPatient[2] 1315.900000
# Patient SliceLocation does not equal Imageposition - ID: 649fd56ef9809019b57261fcf9574d76
# SliceLocation +322.00 ImagePositionPatient[2] 1379.500000
# Patient SliceLocation does not equal Imageposition - ID: a2d9e657a673798f9ebdfec1b361f93a
# SliceLocation +334.00 ImagePositionPatient[2] 1547.000000
# 260 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 8815efa67adb15b2f8cfd49ec992f48e
# SliceLocation 366.20 ImagePositionPatient[2] -366.200012
# Patient SliceLocation does not equal Imageposition - ID: 0708c00f6117ed977bbe1b462b56848c
# SliceLocation +403.00 ImagePositionPatient[2] 1339.000000
# Patient SliceLocation does not equal Imageposition - ID: b229a7697c3efcd6ab82f6f19aff8e8b
# SliceLocation +350.00 ImagePositionPatient[2] 1238.500000
# 300 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 11b09ff9de7382d83f79cc81f89f5894
# SliceLocation +348.00 ImagePositionPatient[2] 1358.500000
# Patient SliceLocation does not equal Imageposition - ID: 1ff6e2a80eb74396e09460c61ae69fb0
# SliceLocation +389.50 ImagePositionPatient[2] 1366.000000
# Duplicate slices for same z-depth - ID: b8bb02d229361a623a4dc57aa0e5c485
# Patient SliceLocation does not equal Imageposition - ID: 665c1913d8e90e57af3b745349d19537
# SliceLocation +371.00 ImagePositionPatient[2] 695.500000
# Patient SliceLocation does not equal Imageposition - ID: ab9e5f1718f2af09030dd33b531f066c
# SliceLocation 385.80 ImagePositionPatient[2] 1435.19995
# Patient SliceLocation does not equal Imageposition - ID: 043ed6cb6054cc13804a3dca342fa4d0
# SliceLocation +350.00 ImagePositionPatient[2] 1384
# Patient SliceLocation does not equal Imageposition - ID: ead64f9269f2200e1d439960a1e069b4
# SliceLocation 329.90 ImagePositionPatient[2] 1352.59998
# Patient slice has no SliceLocation - ID: 4bf6fb574a2ca2da551609e98a573e54
# Patient SliceLocation does not equal Imageposition - ID: dbcb3dbee4f4e75d0672c2a23feb1e3a
# SliceLocation +311.00 ImagePositionPatient[2] 1360.500000
# 340 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 2b89691a0744504491ef91d711d94918
# SliceLocation +158.00 ImagePositionPatient[2] -1237.500000
# Patient SliceLocation does not equal Imageposition - ID: 2950df9632577cb4b3af2dbfe2086b11
# SliceLocation +348.00 ImagePositionPatient[2] 1394.500000
# Patient SliceLocation does not equal Imageposition - ID: 6ddb331865608b8dfb8cac6d873eaf62
# SliceLocation +359.20 ImagePositionPatient[2] 1475.300000
# Patient SliceLocation does not equal Imageposition - ID: a2a4bc7708f6831470d757cd6f32bffe
# SliceLocation +339.10 ImagePositionPatient[2] 1577.900000
# 360 of 1595
# Patient SliceLocation does not equal Imageposition - ID: d2282b0eb61b8d3b090cf8eb76776529
# SliceLocation 345.90 ImagePositionPatient[2] 1265.099000
# 380 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 43f2ef8f53e1aa03bfb6378d0c20a8ac
# SliceLocation 319.45 ImagePositionPatient[2] -319.450012
# Patient SliceLocation does not equal Imageposition - ID: 322bf0acacba9650fa5656b9613c75c8
# SliceLocation -649.38 ImagePositionPatient[2] 649.375
# Patient SliceLocation does not equal Imageposition - ID: b83ce5267f3fd41c7029b4e56724cd08
# SliceLocation 85.20 ImagePositionPatient[2] -1568.80005
# 400 of 1595
# 420 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 2d596b6ead89ab35577fe625a9a17cbb
# SliceLocation -72.10 ImagePositionPatient[2] -1567.59998
# Patient SliceLocation does not equal Imageposition - ID: d7e5640b52c8e092ec277febc81478da
# SliceLocation +358.00 ImagePositionPatient[2] 1362.000000
# Patient SliceLocation does not equal Imageposition - ID: 934f01786c3bdf8eeaf7d8411a3a8f82
# SliceLocation +315.00 ImagePositionPatient[2] 1336.000000
# Patient SliceLocation does not equal Imageposition - ID: c0279b938ac1790f1badfcd4459f5c4c
# SliceLocation 337.80 ImagePositionPatient[2] 1408.69995
# 440 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 404e5dd2b032a223282f5a5e73c05418
# SliceLocation 39.10 ImagePositionPatient[2] -1698.40002
# Patient SliceLocation does not equal Imageposition - ID: ced4f41abff9290b0638b0a25cd5a26d
# SliceLocation +333.00 ImagePositionPatient[2] 1310.000000
# Patient slice has no SliceLocation - ID: 995fc0581ed0e3ba0f97dbd7fe63db59
# 460 of 1595
# Patient SliceLocation does not equal Imageposition - ID: a532c6f9405e6f3a4229ea6e04b0d975
# SliceLocation 303.00 ImagePositionPatient[2] 1559.5
# Patient SliceLocation does not equal Imageposition - ID: af3657cf479490d027ada92b330f80af
# SliceLocation +344.10 ImagePositionPatient[2] 1411.400000
# Patient SliceLocation does not equal Imageposition - ID: af1d0c2fcde369dd1b715460c2f704a2
# SliceLocation 10.20 ImagePositionPatient[2] -1580.80005
# Patient SliceLocation does not equal Imageposition - ID: 98ea0b7d586e5e888e31633772f4df94
# SliceLocation +331.00 ImagePositionPatient[2] 1308.000000
# 480 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 59e4985cd165f3abbe888475ce564f3a
# SliceLocation +333.00 ImagePositionPatient[2] 1457.500000
# Patient SliceLocation does not equal Imageposition - ID: 68a1f729eb1e2a791fe8170ac6631828
# SliceLocation +359.00 ImagePositionPatient[2] 1351.000000
# Patient SliceLocation does not equal Imageposition - ID: 437e42695e7ad0a1cb834e1b3e780516
# SliceLocation 369.000000 ImagePositionPatient[2] 1489.500000
# 500 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 91d0606b85ab7dbc7bab718c1312f2df
# SliceLocation +319.00 ImagePositionPatient[2] 1372.000000
# Patient SliceLocation does not equal Imageposition - ID: 6c56e9802fb6346db58bd5daf160f9be
# SliceLocation +345.60 ImagePositionPatient[2] 1524.900000
# Patient SliceLocation does not equal Imageposition - ID: 6f229187fe608c9eacc567eb74c1458c
# SliceLocation 338.58 ImagePositionPatient[2] -338.575043
# 520 of 1595
# 1100 of 1595
# Patient SliceLocation does not equal Imageposition - ID: a87740afc072074e6c5a2ab787235dde
# SliceLocation +351.00 ImagePositionPatient[2] 1399.000000
# Patient SliceLocation does not equal Imageposition - ID: 61630ec628631f7fe3980f869e1a4fbe
# SliceLocation 363.70 ImagePositionPatient[2] 1512.80005
# 1120 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 013395589c01aa01f8df81d80fb0e2b8
# SliceLocation 56.70 ImagePositionPatient[2] -1514.30005
# Patient SliceLocation does not equal Imageposition - ID: dcf5fd36b9fff9183f63df286bf8eef9
# SliceLocation 278.60 ImagePositionPatient[2] 1429.40002
# 1140 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 6cf71f5017945c9dd8bc0f5126eeef5b
# SliceLocation +355.00 ImagePositionPatient[2] 1429.000000
# Patient SliceLocation does not equal Imageposition - ID: 8b6e16b4e1d1400452956578f8eb97c4
# SliceLocation +394.00 ImagePositionPatient[2] 1202.000000
# 1160 of 1595
# Patient SliceLocation does not equal Imageposition - ID: a15d4fd19fb32f4858f472962c4bb230
# SliceLocation +344.00 ImagePositionPatient[2] 1338.500000
# 1180 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 14248ec22193bed1e087755df5a28509
# SliceLocation +423.40 ImagePositionPatient[2] 1441.599000
# 1200 of 1595
# Patient SliceLocation does not equal Imageposition - ID: a3cb12d3b8d5c64fa55f27208fe13a07
# SliceLocation 85.40 ImagePositionPatient[2] -1549.09998
# 1220 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 6f43af3f636f37b9695b58378f9265cc
# SliceLocation 62.90 ImagePositionPatient[2] -1686.09998
# Patient SliceLocation does not equal Imageposition - ID: 006b96310a37b36cccb2ab48d10b49a3
# SliceLocation +364.50 ImagePositionPatient[2] 521.500000
# Patient SliceLocation does not equal Imageposition - ID: bfb3e2d11c149036bbe12566ef6b933c
# SliceLocation +344.10 ImagePositionPatient[2] 1322.900000
# Patient SliceLocation does not equal Imageposition - ID: 521924ac2f00a62cc63f679de7e599cd
# SliceLocation +370.00 ImagePositionPatient[2] 1383.000000
# 1240 of 1595
# Patient SliceLocation does not equal Imageposition - ID: f76143416ee2c8e1251f45f108fed468
# SliceLocation +333.00 ImagePositionPatient[2] 706.000000
# Patient SliceLocation does not equal Imageposition - ID: bb94bc5dd4656a2387bafb6098311175
# SliceLocation 333.30 ImagePositionPatient[2] 1469.19995
# 1260 of 1595
# Patient slice has no SliceLocation - ID: 08acb3440eb23385724d006403feb585
# Patient SliceLocation does not equal Imageposition - ID: d3eaad692dc96b1a1765076716f55421
# SliceLocation +364.00 ImagePositionPatient[2] 1654.000000
# 1280 of 1595
# Patient slice has no SliceLocation - ID: a4fa7dd73e3017b97ac6674a10fac216
# Patient SliceLocation does not equal Imageposition - ID: b61b1911d3631bee521fcda3a3e568a1
# SliceLocation 320.50 ImagePositionPatient[2] 1611
# 1300 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 9f12d2d6134af032932ed37776c6d09f
# SliceLocation +332.70 ImagePositionPatient[2] 1344.800000
# 1320 of 1595
# Patient SliceLocation does not equal Imageposition - ID: adc3bbc63d40f8761c59be10f1e504c3
# SliceLocation -616.55 ImagePositionPatient[2] 616.549988
# Patient SliceLocation does not equal Imageposition - ID: 31e82ed2c875eae8dfbfd70ac440458a
# SliceLocation +347.00 ImagePositionPatient[2] 1362.500000
# 1340 of 1595
# Patient SliceLocation does not equal Imageposition - ID: cd6be62834c72756738935f904ec9c2c
# SliceLocation +275.00 ImagePositionPatient[2] 1427.500000
# 1360 of 1595
# Patient SliceLocation does not equal Imageposition - ID: e58b78dc31d80a50285816f4ecd661e3
# SliceLocation +322.00 ImagePositionPatient[2] 1333.500000
# Patient SliceLocation does not equal Imageposition - ID: 359951e3d2768249211361665b99b735
# SliceLocation +300.00 ImagePositionPatient[2] 1337.500000
# 1380 of 1595
# Patient SliceLocation does not equal Imageposition - ID: e1e47812eecd80466cf7f5b0160de446
# SliceLocation +352.00 ImagePositionPatient[2] 1292.000000
# Patient slice has no SliceLocation - ID: 809ae218d8b4a973d11358264e4a0823
# Patient SliceLocation does not equal Imageposition - ID: d244870d213a21efa86e86c951d8c9a2
# SliceLocation 240.20 ImagePositionPatient[2] -1588.30005
# Patient slice has no SliceLocation - ID: bbf7a3e138f9353414f2d51f0c363561
# 1400 of 1595
# Patient SliceLocation does not equal Imageposition - ID: f0f72264cd822301852578cc71288d3c
# SliceLocation +367.00 ImagePositionPatient[2] -357.500000
# 1420 of 1595
# Patient slice has no SliceLocation - ID: 70671fa94231eb377e8ac7cba4650dfb
# Patient SliceLocation does not equal Imageposition - ID: f42a0343e5b5154c6a184fc955d8f20f
# SliceLocation +427.00 ImagePositionPatient[2] 1372.500000
# Patient SliceLocation does not equal Imageposition - ID: 02801e3bbcc6966cb115a962012c35df
# SliceLocation +375.80 ImagePositionPatient[2] 1261.199000
# Patient SliceLocation does not equal Imageposition - ID: 494c42cb61c1e4a02504c16fe09a8129
# SliceLocation 303.10 ImagePositionPatient[2] -1398.40002
# Patient SliceLocation does not equal Imageposition - ID: 2b55d9c3f8e05951c87e90d2361aca6a
# SliceLocation +360.00 ImagePositionPatient[2] 1401.500000
# 1440 of 1595
# Patient SliceLocation does not equal Imageposition - ID: a59b1dc7e417fea605b34a5204f61f9d
# SliceLocation 397.30 ImagePositionPatient[2] 1372.19995
# 1460 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 39ebb8121ea6faec0405a4e8db883b55
# SliceLocation +304.00 ImagePositionPatient[2] 1408.500000
# Patient SliceLocation does not equal Imageposition - ID: 64a5a866461a3b6006efb0075e04dffe
# SliceLocation +320.00 ImagePositionPatient[2] 1353.000000
# 1480 of 1595
# 1500 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 993f1e68290d591f755669e97b49b4f4
# SliceLocation 57.90 ImagePositionPatient[2] -1762.59998
# Patient SliceLocation does not equal Imageposition - ID: 5f19d1c7bd7ceb691639cab9c1c2cb19
# SliceLocation +414.50 ImagePositionPatient[2] 1584.500000
# 1520 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 9f73628a5e06cfc6723f3ee2ae4b96c4
# SliceLocation 63.60 ImagePositionPatient[2] -1674.40002
# 1540 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 5782e6873c666529c6a66421acb043dc
# SliceLocation 496.90 ImagePositionPatient[2] 1408.59998
# Patient SliceLocation does not equal Imageposition - ID: 88523579f4e325351665753e903cfdf5
# SliceLocation +292.00 ImagePositionPatient[2] 1251.000000
# Patient SliceLocation does not equal Imageposition - ID: 7b84056d69644df2a9452a1746d14d39
# SliceLocation +320.00 ImagePositionPatient[2] 1384.000000
# Patient slice has no SliceLocation - ID: 3187b6cf14ed2cbe611b01da5e161f21
# 1580 of 1595
# Patient SliceLocation does not equal Imageposition - ID: 648c99653d512edc1d28dd8e7054ceab
# SliceLocation 230.40 ImagePositionPatient[2] -230.399963
