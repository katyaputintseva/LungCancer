# %%
import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.3
set_session(tf.Session(config=config))

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
features = ['Malignancy', 'Diameter', 'Lobulation', 'Spiculation']

# %%
# %run 'CNNBlocks.ipynb'
# %run 'modelArchitecture.ipynb'
# %run 'batchGenerator.ipynb'

# %%
#Compiling model with branching on the level of Dense block
model = compileModel((1,64,64,64),1e-3)
# Out:
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(8, (3, 3, 3), padding="same", kernel_regularizer=<keras.reg..., data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:12: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:6: UserWarning: Update your `AveragePooling3D` call to the Keras 2 API: `AveragePooling3D(data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:7: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /opt/anaconda/lib/python3.5/site-packages/keras/legacy/layers.py:456: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(24, (3, 3, 3), padding="same", kernel_regularizer=<keras.reg..., data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: UserWarning: Update your `AveragePooling3D` call to the Keras 2 API: `AveragePooling3D(data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:11: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(48, (3, 3, 3), padding="same", kernel_regularizer=<keras.reg..., data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:14: UserWarning: Update your `AveragePooling3D` call to the Keras 2 API: `AveragePooling3D(data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:15: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(64, (3, 3, 3), padding="same", kernel_regularizer=<keras.reg..., data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:18: UserWarning: Update your `AveragePooling3D` call to the Keras 2 API: `AveragePooling3D(data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:19: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(65, (3, 3, 3), padding="same", kernel_regularizer=<keras.reg..., data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(32, kernel_regularizer=<keras.reg...)`
#   app.launch_new_instance()
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="softplus", name="Malignancy", kernel_regularizer=<keras.reg...)`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="softplus", name="Diameter", kernel_regularizer=<keras.reg...)`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="softplus", name="Lobulation", kernel_regularizer=<keras.reg...)`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="softplus", name="Spiculation", kernel_regularizer=<keras.reg...)`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:31: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=[<tf.Tenso..., inputs=Tensor("in...)`
# Compiling model...

# %%
#Compiling model with branching on the level of Convolution block #5
model = compileModelDeepBranching((1,64,64,64),1e-3)
# Out:
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(8, (3, 3, 3), kernel_regularizer=<keras.reg..., padding="same", data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:12: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:6: UserWarning: Update your `AveragePooling3D` call to the Keras 2 API: `AveragePooling3D(data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:7: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /opt/anaconda/lib/python3.5/site-packages/keras/legacy/layers.py:456: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(24, (3, 3, 3), kernel_regularizer=<keras.reg..., padding="same", data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: UserWarning: Update your `AveragePooling3D` call to the Keras 2 API: `AveragePooling3D(data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:11: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(48, (3, 3, 3), kernel_regularizer=<keras.reg..., padding="same", data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:14: UserWarning: Update your `AveragePooling3D` call to the Keras 2 API: `AveragePooling3D(data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:15: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(64, (3, 3, 3), kernel_regularizer=<keras.reg..., padding="same", data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:18: UserWarning: Update your `AveragePooling3D` call to the Keras 2 API: `AveragePooling3D(data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:19: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(65, (3, 3, 3), kernel_regularizer=<keras.reg..., padding="same", data_format="channels_first")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(32, kernel_regularizer=<keras.reg...)`
#   app.launch_new_instance()
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, name="Malignancy", kernel_regularizer=<keras.reg..., activation="softplus")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, name="Diameter", kernel_regularizer=<keras.reg..., activation="softplus")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, name="Lobulation", kernel_regularizer=<keras.reg..., activation="softplus")`
# Compiling model...
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, name="Spiculation", kernel_regularizer=<keras.reg..., activation="softplus")`
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:55: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=[<tf.Tenso...)`

# %%
# model_64.load_weights('/home/katya/LungCancer/Katya/CNN_v1/model_v1_weights_temp64.h5')

nbEpochs = 15

modelPath = '/home/katya/LungCancer/Katya/CNN_v2/model_and_weights/LUNA_model_v2_test.h5'
model, lossHist = trainModel(model, modelPath, batchSize=50, nbEpoch = nbEpochs, stepsPerEpoch = 100)

model.save_weights('/home/katya/LungCancer/Katya/CNN_v2/model_and_weights/LUNA_model_v2_weights_test.h5')
# Out:
# Loading positive patches
# The number of samples for true category constitutes 3570
# Loading negative patches
# The number of samples for random category constitutes 5328
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=0, steps_per_epoch=100, epochs=1, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# Epoch 1/1
# 100/100 [==============================] - 487s - loss: 1.7197 - Malignancy_loss: 0.1246 - Diameter_loss: 0.2061 - Lobulation_loss: 0.1463 - Spiculation_loss: 0.1310 - val_loss: 1.6518 - val_Malignancy_loss: 0.1169 - val_Diameter_loss: 0.1220 - val_Lobulation_loss: 0.1448 - val_Spiculation_loss: 0.1584
# Epoch 2/2
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=1, steps_per_epoch=100, epochs=2, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# 100/100 [==============================] - 487s - loss: 1.3869 - Malignancy_loss: 0.0937 - Diameter_loss: 0.0602 - Lobulation_loss: 0.0610 - Spiculation_loss: 0.0643 - val_loss: 1.3962 - val_Malignancy_loss: 0.0921 - val_Diameter_loss: 0.0653 - val_Lobulation_loss: 0.0742 - val_Spiculation_loss: 0.0589
# Epoch 3/3
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=2, steps_per_epoch=100, epochs=3, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# 100/100 [==============================] - 487s - loss: 1.3423 - Malignancy_loss: 0.0842 - Diameter_loss: 0.0466 - Lobulation_loss: 0.0513 - Spiculation_loss: 0.0548 - val_loss: 1.3650 - val_Malignancy_loss: 0.0895 - val_Diameter_loss: 0.0545 - val_Lobulation_loss: 0.0573 - val_Spiculation_loss: 0.0585
# Epoch 4/4
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=3, steps_per_epoch=100, epochs=4, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# 100/100 [==============================] - 487s - loss: 1.3403 - Malignancy_loss: 0.0864 - Diameter_loss: 0.0453 - Lobulation_loss: 0.0495 - Spiculation_loss: 0.0541 - val_loss: 1.3356 - val_Malignancy_loss: 0.0787 - val_Diameter_loss: 0.0481 - val_Lobulation_loss: 0.0518 - val_Spiculation_loss: 0.0521
# Epoch 5/5
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=4, steps_per_epoch=100, epochs=5, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# 100/100 [==============================] - 487s - loss: 1.3391 - Malignancy_loss: 0.0862 - Diameter_loss: 0.0445 - Lobulation_loss: 0.0493 - Spiculation_loss: 0.0544 - val_loss: 1.3450 - val_Malignancy_loss: 0.0830 - val_Diameter_loss: 0.0455 - val_Lobulation_loss: 0.0540 - val_Spiculation_loss: 0.0581
# Epoch 6/6
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=5, steps_per_epoch=100, epochs=6, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# 100/100 [==============================] - 487s - loss: 1.3388 - Malignancy_loss: 0.0851 - Diameter_loss: 0.0438 - Lobulation_loss: 0.0509 - Spiculation_loss: 0.0547 - val_loss: 1.3391 - val_Malignancy_loss: 0.0830 - val_Diameter_loss: 0.0490 - val_Lobulation_loss: 0.0512 - val_Spiculation_loss: 0.0517
# Epoch 7/7
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=6, steps_per_epoch=100, epochs=7, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# 100/100 [==============================] - 486s - loss: 1.3311 - Malignancy_loss: 0.0844 - Diameter_loss: 0.0426 - Lobulation_loss: 0.0483 - Spiculation_loss: 0.0517 - val_loss: 1.3320 - val_Malignancy_loss: 0.0820 - val_Diameter_loss: 0.0449 - val_Lobulation_loss: 0.0479 - val_Spiculation_loss: 0.0531
# Epoch 8/8
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=7, steps_per_epoch=100, epochs=8, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# 100/100 [==============================] - 581s - loss: 1.3308 - Malignancy_loss: 0.0838 - Diameter_loss: 0.0421 - Lobulation_loss: 0.0488 - Spiculation_loss: 0.0523 - val_loss: 1.3319 - val_Malignancy_loss: 0.0833 - val_Diameter_loss: 0.0442 - val_Lobulation_loss: 0.0515 - val_Spiculation_loss: 0.0492
# Epoch 9/9
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=8, steps_per_epoch=100, epochs=9, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# 100/100 [==============================] - 487s - loss: 1.3262 - Malignancy_loss: 0.0840 - Diameter_loss: 0.0419 - Lobulation_loss: 0.0457 - Spiculation_loss: 0.0509 - val_loss: 1.3137 - val_Malignancy_loss: 0.0751 - val_Diameter_loss: 0.0425 - val_Lobulation_loss: 0.0453 - val_Spiculation_loss: 0.0473
# Epoch 10/10
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=9, steps_per_epoch=100, epochs=10, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# 100/100 [==============================] - 601s - loss: 1.3282 - Malignancy_loss: 0.0850 - Diameter_loss: 0.0416 - Lobulation_loss: 0.0479 - Spiculation_loss: 0.0501 - val_loss: 1.3289 - val_Malignancy_loss: 0.0827 - val_Diameter_loss: 0.0434 - val_Lobulation_loss: 0.0484 - val_Spiculation_loss: 0.0510
# Epoch 11/11
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=10, steps_per_epoch=100, epochs=11, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# 100/100 [==============================] - 558s - loss: 1.3203 - Malignancy_loss: 0.0809 - Diameter_loss: 0.0398 - Lobulation_loss: 0.0471 - Spiculation_loss: 0.0492 - val_loss: 1.3285 - val_Malignancy_loss: 0.0835 - val_Diameter_loss: 0.0447 - val_Lobulation_loss: 0.0492 - val_Spiculation_loss: 0.0477
# Epoch 12/12
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=11, steps_per_epoch=100, epochs=12, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# 100/100 [==============================] - 605s - loss: 1.3261 - Malignancy_loss: 0.0826 - Diameter_loss: 0.0404 - Lobulation_loss: 0.0476 - Spiculation_loss: 0.0521 - val_loss: 1.3284 - val_Malignancy_loss: 0.0844 - val_Diameter_loss: 0.0430 - val_Lobulation_loss: 0.0493 - val_Spiculation_loss: 0.0484
# Epoch 13/13
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=12, steps_per_epoch=100, epochs=13, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# 100/100 [==============================] - 534s - loss: 1.3255 - Malignancy_loss: 0.0849 - Diameter_loss: 0.0402 - Lobulation_loss: 0.0465 - Spiculation_loss: 0.0506 - val_loss: 1.3345 - val_Malignancy_loss: 0.0834 - val_Diameter_loss: 0.0433 - val_Lobulation_loss: 0.0517 - val_Spiculation_loss: 0.0528
# Epoch 14/14
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=13, steps_per_epoch=100, epochs=14, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
# 100/100 [==============================] - 602s - loss: 1.3230 - Malignancy_loss: 0.0834 - Diameter_loss: 0.0396 - Lobulation_loss: 0.0465 - Spiculation_loss: 0.0502 - val_loss: 1.3199 - val_Malignancy_loss: 0.0786 - val_Diameter_loss: 0.0409 - val_Lobulation_loss: 0.0461 - val_Spiculation_loss: 0.0510
# Epoch 15/15
# /opt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:59: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., initial_epoch=14, steps_per_epoch=100, epochs=15, callbacks=[<keras.ca..., validation_steps=20, validation_data=<generator...)`
#  64/100 [==================>...........] - ETA: 203s - loss: 1.3197 - Malignancy_loss: 0.0810 - Diameter_loss: 0.0411 - Lobulation_loss: 0.0453 - Spiculation_loss: 0.0491

# %%
plt.figure(figsize=[10,7])
plt.grid(True, ls='--', lw=0.5, alpha=0.5, dash_capstyle = 'round', c='gray')
plt.xlabel('Epoch #', fontsize=15)
plt.ylabel('Loss', fontsize=15)

labels=list(lossHist.keys())

for i,key in enumerate(lossHist):
    plt.plot([x for x in range(nbEpochs)], lossHist[key], 'o-', label=labels[i])
    plt.legend()
    
plt.savefig('/home/katya/LungCancer/Katya/CNN_v2/figures/' + str(version) + '.png')

# %%
version = 7

# %%
for feature in features:
    plt.figure(figsize=[10,8])
    plt.grid(True, ls='--', lw=0.5, alpha=0.5, dash_capstyle = 'round', c='gray')

    plt.plot([x for x in range(nbEpochs)], lossHist[feature+'_loss'], label=feature+'_loss')
    plt.plot([x for x in range(nbEpochs)], lossHist['val_'+feature+'_loss'], label='val_'+feature+'_loss')
    plt.title(feature)
    plt.legend()
    plt.savefig('/home/katya/LungCancer/Katya/CNN_v2/figures/'+str(version)+'.'+feature+'.png')
